# %%
# Import the MonitoredRandomCircuit class
from monitored_random_circuit import MonitoredRandomCircuit

# Define parameters
pm = 0.5
pf = 0.1
num_steps = 100
num_runs = 200
system_sizes = [4, 6, 8]

# Plot the second Rényi entropy as a function of time for different system sizes
MonitoredRandomCircuit.plot_renyi_entropy_vs_time(system_sizes, pm, pf, num_steps, num_runs)
# Out:
# Final measurement results for L=4:
# {'0000': 200.0}
# /Users/youtao/miniconda3/envs/scicomp/lib/python3.12/site-packages/matplotlib/cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# /Users/youtao/miniconda3/envs/scicomp/lib/python3.12/site-packages/matplotlib/cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
# Final measurement results for L=6:
# {'000000': 200.0}
# Final measurement results for L=8:
# {'00000000': 200.0}
